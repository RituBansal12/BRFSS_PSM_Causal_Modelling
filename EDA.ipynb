# %%
import pandas as pd
import numpy as np

# %%
metadata_file = 'data/LLCP2023_metadata.csv'
df_metadata = pd.read_csv(metadata_file)
df_metadata
# Out:
#      SAS Variable Name                   Label           Section Name Value  \
# 0               _STATE         State FIPS Code  Record Identification     1
# 1               _STATE         State FIPS Code  Record Identification     2
# 2               _STATE         State FIPS Code  Record Identification     4
# 3               _STATE         State FIPS Code  Record Identification     5
# 4               _STATE         State FIPS Code  Record Identification     6
# ...                ...                     ...                    ...   ...
# 1845          _RFSEAT3  Always Wear Seat Belts   Calculated Variables     2
# 1846          _RFSEAT3  Always Wear Seat Belts   Calculated Variables     9
# 1847          _DRNKDRV    Drinking and Driving   Calculated Variables     1
# 1848          _DRNKDRV    Drinking and Driving   Calculated Variables     2
# 1849          _DRNKDRV    Drinking and Driving   Calculated Variables     9
#
#                                          Value Label
# ...

# %%
df_metadata['Section Name'].nunique()
# Out:
# 58

# %%
pd.DataFrame({'Section Name': df_metadata['Section Name'].unique()})
# Out:
#                                 Section Name
# 0                      Record Identification
# 1                     Land Line Introduction
# 2                    Cell Phone Introduction
# 3                             Respondent Sex
# 4                              Health Status
# 5                               Healthy Days
# 6                         Health Care Access
# 7               Exercise (Physical Activity)
# 8                     Hypertension Awareness
# 9                      Cholesterol Awareness
# 10                 Chronic Health Conditions
# 11                              Demographics
# 12                                Disability
# 13                                     Falls
# 14                               Tobacco Use
# 15                       Alcohol Consumption
# 16                              Immunization
# 17                                  HIV/AIDS
# 18     Seatbelt Use and Drinking and Driving
# 19                   Long-term COVID Effects
# ...

# %%
tmp = df_metadata[df_metadata['Section Name'].str.contains('Calculated')]
tmp
# Out:
#      SAS Variable Name                              Label  \
# 1556           _RFHLTH  Adults with good or better health
# 1557           _RFHLTH  Adults with good or better health
# 1558           _RFHLTH  Adults with good or better health
# 1559          _PHYS14D    Computed Physical Health Status
# 1560          _PHYS14D    Computed Physical Health Status
# ...                ...                                ...
# 1845          _RFSEAT3             Always Wear Seat Belts
# 1846          _RFSEAT3             Always Wear Seat Belts
# 1847          _DRNKDRV               Drinking and Driving
# 1848          _DRNKDRV               Drinking and Driving
# 1849          _DRNKDRV               Drinking and Driving
#
#               Section Name Value  \
# 1556  Calculated Variables     1
# 1557  Calculated Variables     2
# 1558  Calculated Variables     9
# 1559  Calculated Variables     1
# 1560  Calculated Variables     2
# ...                    ...   ...
# ...
