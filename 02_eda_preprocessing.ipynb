# %%
import pandas as pd

# Load the metadata file
metadata_path = "data/LLCP2023_metadata.csv"
metadata = pd.read_csv(metadata_path)

# View the first few rows of the metadata
print(metadata.head())
# Out:
#   SAS Variable Name            Label           Section Name Value Value Label
# 0            _STATE  State FIPS Code  Record Identification     1     Alabama
# 1            _STATE  State FIPS Code  Record Identification     2      Alaska
# 2            _STATE  State FIPS Code  Record Identification     4     Arizona
# 3            _STATE  State FIPS Code  Record Identification     5    Arkansas
# 4            _STATE  State FIPS Code  Record Identification     6  California

# %%
metadata.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850 entries, 0 to 1849
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   SAS Variable Name  1850 non-null   object
#  1   Label              1850 non-null   object
#  2   Section Name       1850 non-null   object
#  3   Value              1849 non-null   object
#  4   Value Label        1838 non-null   object
# dtypes: object(5)
# memory usage: 72.4+ KB

# %%
# Get unique section names to explore the themes
section_names = metadata['Section Name'].dropna().unique()

# Print all section names to choose relevant ones
for name in sorted(section_names):
    print(name)
# Out:
# Adverse Childhood Experiences
# Alcohol Consumption
# Arthritis
# Aspirin for CVD Prevention
# Breast and Cervical Cancer Screening
# COVID Vaccination
# Calculated Race Variables
# Calculated Variables
# Cancer Survivorship: Course of Treatment
# Cancer Survivorship: Pain Management
# Cancer Survivorship: Type of Cancer
# Caregiver
# Cell Phone Introduction
# Childhood Asthma Prevalence
# Child Demographic Variables
# Child Weighting Variables
# Cholesterol Awareness
# Chronic Health Conditions
# Cognitive Decline
# Colorectal Cancer Screening
# Demographics
# Diabetes
# Disability
# Excess Sun Exposure
# Exercise (Physical Activity)
# Falls
# Firearm Safety
# HIV/AIDS
# HPV Vaccination
# Healthy Days
# Health Care Access
# Health Status
# Heart Attack and Stroke
# Hypertension Awareness
# Immunization
# Indoor Tanning
# Land Line Introduction
# Long-term COVID Effects
# Lung Cancer Screening
# Marijuana Use
# Other Tobacco Use
# Place of Flu Vaccination
# Pre-Diabetes
# Prostate Cancer Screening
# Questionnaire Language
# Questionnaire Version
# Random Child Selection
# Reactions to Race
# Record Identification
# Respondent Sex
# Seatbelt Use and Drinking and Driving
# Sexual Orientation
# Social Determinants
# Tetanus Diphtheria (Tdap) (Adults)
# Tobacco Cessation
# Tobacco Use
# Urban Rural
# Weighting Variables

# %%
import re

# Clean section names more aggressively using regex
def clean_section_name(name):
    if pd.isnull(name):
        return name
    name = name.lower()
    name = re.sub(r'\(.*?\)', '', name)         # remove things in parentheses
    name = re.sub(r'[^a-z0-9 ]+', '', name)     # remove punctuation except space
    name = re.sub(r'\s+', '_', name.strip())    # replace whitespace with underscores
    return name

metadata['Section Name Clean'] = metadata['Section Name'].apply(clean_section_name)

# Show unique cleaned names
section_names = metadata['Section Name Clean'].dropna().unique()
for name in sorted(section_names):
    print(name)
# Out:
# adversechildhoodexperiences
# alcoholconsumption
# arthritis
# aspirinforcvdprevention
# breastandcervicalcancerscreening
# calculatedracevariables
# calculatedvariables
# cancersurvivorshipcourseoftreatment
# cancersurvivorshippainmanagement
# cancersurvivorshiptypeofcancer
# caregiver
# cellphoneintroduction
# childdemographicvariables
# childhoodasthmaprevalence
# childweightingvariables
# cholesterolawareness
# chronichealthconditions
# cognitivedecline
# colorectalcancerscreening
# covidvaccination
# demographics
# diabetes
# disability
# excesssunexposure
# exercise
# falls
# firearmsafety
# healthcareaccess
# healthstatus
# healthydays
# heartattackandstroke
# hivaids
# hpvvaccination
# hypertensionawareness
# immunization
# indoortanning
# landlineintroduction
# longtermcovideffects
# lungcancerscreening
# marijuanause
# othertobaccouse
# placeoffluvaccination
# prediabetes
# prostatecancerscreening
# questionnairelanguage
# questionnaireversion
# randomchildselection
# reactionstorace
# recordidentification
# respondentsex
# seatbeltuseanddrinkinganddriving
# sexualorientation
# socialdeterminants
# tetanusdiphtheria
# tobaccocessation
# tobaccouse
# urbanrural
# weightingvariables

# %%
# Define secttions of interest
sections_interest = [
    'adversechildhoodexperiences',
    'alcoholconsumption',
    'caregiver',
    'chronichealthconditions',
    'cognitivedecline',
    'demographics',
    'disability',
    'healthcareaccess',
    'healthstatus',
    'healthydays', # This section contains the result variable
    'marijuanause',
    'othertobaccouse',
    'respondentsex',
    'sexualorientation',
    'socialdeterminants',
    'tobaccouse',
    'urbanrural', 
    'exercise'
]

# Filter metadata to include only those sections
df_subset = metadata[metadata['Section Name Clean'].isin(sections_interest)]

# %%
df_subset2 = df_subset[['SAS Variable Name', 'Section Name Clean', 'Label']].drop_duplicates()

# %%
# Display the entire DataFrame of confounder variables
df_subset2 = df_subset2.reset_index(drop=True)
pd.set_option('display.max_rows', None)

display(df_subset2)
# Out:
#     SAS Variable Name           Section Name Clean  \
# 0              SEXVAR                respondentsex
# 1             GENHLTH                 healthstatus
# 2            PHYSHLTH                  healthydays
# 3            MENTHLTH                  healthydays
# 4            POORHLTH                  healthydays
# 5            PRIMINS1             healthcareaccess
# 6            PERSDOC3             healthcareaccess
# 7            MEDCOST1             healthcareaccess
# 8            CHECKUP1             healthcareaccess
# 9            EXERANY2                     exercise
# 10           EXRACT12                     exercise
# 11           EXEROFT1                     exercise
# 12           EXERHMM1                     exercise
# 13           EXRACT22                     exercise
# 14           EXEROFT2                     exercise
# 15           EXERHMM2                     exercise
# 16           STRENGTH                     exercise
# 17           CVDINFR4      chronichealthconditions
# 18           CVDCRHD4      chronichealthconditions
# 19           CVDSTRK3      chronichealthconditions
# 20            ASTHMA3      chronichealthconditions
# 21            ASTHNOW      chronichealthconditions
# 22           CHCSCNC1      chronichealthconditions
# 23           CHCOCNC1      chronichealthconditions
# 24           CHCCOPD3      chronichealthconditions
# 25           ADDEPEV3      chronichealthconditions
# 26           CHCKDNY2      chronichealthconditions
# 27           HAVARTH4      chronichealthconditions
# 28           DIABETE4      chronichealthconditions
# 29           DIABAGE4      chronichealthconditions
# 30            MARITAL                 demographics
# 31              EDUCA                 demographics
# 32           RENTHOM1                 demographics
# 33           NUMHHOL4                 demographics
# 34           NUMPHON4                 demographics
# 35           CPDEMO1C                 demographics
# 36           VETERAN3                 demographics
# 37            EMPLOY1                 demographics
# 38           CHILDREN                 demographics
# 39            INCOME3                 demographics
# 40           PREGNANT                 demographics
# 41            WEIGHT2                 demographics
# 42            HEIGHT3                 demographics
# 43               DEAF                   disability
# 44              BLIND                   disability
# 45             DECIDE                   disability
# 46           DIFFWALK                   disability
# 47           DIFFDRES                   disability
# 48           DIFFALON                   disability
# 49           SMOKE100                   tobaccouse
# 50           SMOKDAY2                   tobaccouse
# 51            USENOW3                   tobaccouse
# 52           ECIGNOW2                   tobaccouse
# 53            ALCDAY4           alcoholconsumption
# 54           AVEDRNK3           alcoholconsumption
# 55           DRNK3GE5           alcoholconsumption
# 56           MAXDRNKS           alcoholconsumption
# 57           CIMEMLO1             cognitivedecline
# 58            CDWORRY             cognitivedecline
# 59           CDDISCU1             cognitivedecline
# 60            CDHOUS1             cognitivedecline
# 61           CDSOCIA1             cognitivedecline
# 62           CAREGIV1                    caregiver
# 63           CRGVREL4                    caregiver
# 64           CRGVLNG1                    caregiver
# 65           CRGVHRS1                    caregiver
# 66           CRGVPRB3                    caregiver
# 67           CRGVALZD                    caregiver
# 68           CRGVPER1                    caregiver
# 69           CRGVHOU1                    caregiver
# 70           CRGVEXPT                    caregiver
# 71           MENTCIGS              othertobaccouse
# 72           MENTECIG              othertobaccouse
# 73           HEATTBCO              othertobaccouse
# 74             SOMALE            sexualorientation
# 75           SOFEMALE            sexualorientation
# 76           MARIJAN1                 marijuanause
# 77           MARJSMOK                 marijuanause
# 78            MARJEAT                 marijuanause
# 79           MARJVAPE                 marijuanause
# 80            MARJDAB                 marijuanause
# 81           MARJOTHR                 marijuanause
# 82           ACEDEPRS  adversechildhoodexperiences
# 83           ACEDRINK  adversechildhoodexperiences
# 84           ACEDRUGS  adversechildhoodexperiences
# 85           ACEPRISN  adversechildhoodexperiences
# 86           ACEDIVRC  adversechildhoodexperiences
# 87           ACEPUNCH  adversechildhoodexperiences
# 88           ACEHURT1  adversechildhoodexperiences
# 89           ACESWEAR  adversechildhoodexperiences
# 90           ACETOUCH  adversechildhoodexperiences
# 91           ACETTHEM  adversechildhoodexperiences
# 92           ACEHVSEX  adversechildhoodexperiences
# 93           ACEADSAF  adversechildhoodexperiences
# 94           ACEADNED  adversechildhoodexperiences
# 95           LSATISFY           socialdeterminants
# 96           EMTSUPRT           socialdeterminants
# 97           SDLONELY           socialdeterminants
# 98           SDHEMPLY           socialdeterminants
# 99           FOODSTMP           socialdeterminants
# 100          SDHFOOD1           socialdeterminants
# 101          SDHBILLS           socialdeterminants
# 102          SDHUTILS           socialdeterminants
# 103          SDHTRNSP           socialdeterminants
# 104          SDHSTRE1           socialdeterminants
# 105          _METSTAT                   urbanrural
# 106          _URBSTAT                   urbanrural
#
#                                                  Label
# 0                                    Sex of Respondent
# 1                                       General Health
# 2              Number of Days Physical Health Not Good
# 3                Number of Days Mental Health Not Good
# 4                       Poor Physical or Mental Health
# 5    What is Current Primary Source of Health Insur...
# 6                  Have Personal Health Care Provider?
# 7                       Could Not Afford To See Doctor
# 8            Length of time since last routine checkup
# 9                             Exercise in Past 30 Days
# 10                           Type of Physical Activity
# 11   How Many Times Walking, Running, Jogging, or S...
# 12   Minutes or Hours Walking, Running, Jogging, or...
# 13   Other Type of Physical Activity Giving Most Ex...
# 14   How Many Times Walking, Running, Jogging, or S...
# 15   Minutes or Hours Walking, Running, Jogging, or...
# 16   How many times did you do physical activities ...
# 17                    Ever Diagnosed with Heart Attack
# 18   Ever Diagnosed with Angina or Coronary Heart D...
# 19                        Ever Diagnosed with a Stroke
# 20                                Ever Told Had Asthma
# 21                                   Still Have Asthma
# 22   (Ever told) (you had) skin cancer that is not ...
# 23   (Ever told) (you had)  melanoma or any other t...
# 24   Ever told you had C.O.P.D. emphysema or chroni...
# 25           (Ever told) you had a depressive disorder
# 26                  Ever told you have kidney disease?
# 27                                  Told Had Arthritis
# 28                        (Ever told) you had diabetes
# 29                Age When First Told You Had Diabetes
# 30                                      Marital Status
# 31                                     Education Level
# 32                                    Own or Rent Home
# 33                       Household Landline Telephones
# 34                         Residential Landline Phones
# 35     Do you have a cell phone for your personal use?
# 36                                   Are You A Veteran
# 37                                   Employment Status
# 38                     Number of Children in Household
# 39                                        Income Level
# 40                                    Pregnancy Status
# 41                           Reported Weight in Pounds
# 42                  Reported Height in Feet and Inches
# 43   Are you deaf or do you have serious difficulty...
# 44                          Blind or Difficulty seeing
# 45             Difficulty Concentrating or Remembering
# 46               Difficulty Walking or Climbing Stairs
# 47                      Difficulty Dressing or Bathing
# 48                      Difficulty Doing Errands Alone
# 49                      Smoked at Least 100 Cigarettes
# 50                       Frequency of Days Now Smoking
# 51                   Use of Smokeless Tobacco Products
# 52   Do you now use e-cigarettes, or vaping product...
# 53              Days in past 30 had alcoholic beverage
# 54             Avg alcoholic drinks per day in past 30
# 55                                      Binge Drinking
# 56         Most drinks on single occasion past 30 days
# 57   Have you experienced difficulties with thinkin...
# 58   Are you worried about these difficulties with ...
# 59   Have you discussed your difficulties with thin...
# 60   Given up day-to-day chores due to difficulties...
# 61   Does difficulties with thinking or memory inte...
# 62          Provided regular care for family or friend
# 63   Relationship Of Person To Whom You Are Giving ...
# 64                  How Long Provided Care For Person.
# 65      How Many Hours Do You Provide Care For Person?
# 66   What Is The Major Health Problem, Illness, Dis...
# 67   Does Person Being Cared For Have Alzheimer's D...
# 68                               Managed personal care
# 69                             Managed household tasks
# 70   Do you expect to have a relative you will need...
# 71            Do you usually smoke menthol cigarettes?
# 72            Do you usually use menthol e-cigarettes?
# 73          Have you heard of heated tobacco products?
# 74                                  Sexual orientation
# 75                                  Sexual orientation
# 76   During the past 30 days, on how many days did ...
# 77                Did you smoke marijuana or cannabis?
# 78                  Did you eat marijuana or cannabis?
# 79                 Did you vape marijuana or cannabis?
# 80                  Did you dab marijuana or cannabis?
# 81   Did you use marijuana or cannabis some other way?
# 82   Live With Anyone Depressed, Mentally Ill, Or S...
# 83              Live With a Problem Drinker/Alcoholic?
# 84   Live With Anyone Who Used Illegal Drugs or Abu...
# 85   Live With Anyone Who Served TIme in Prison or ...
# 86               Were Your Parents Divorced/Seperated?
# 87      How Often Did Your Parents Beat Each Other Up?
# 88   How Often Did A Parent Physically Hurt You In ...
# 89                How Often Did A Parent Swear At You?
# 90       How Often Did Anyone Ever Touch You Sexually?
# 91   How Often Did Anyone Make You Touch Them Sexua...
# 92    How Often Did Anyone Ever Force You to Have Sex?
# 93       Did an adult make you feel safe and protected
# 94         Did an adult make sure basic needs were met
# 95                              Satisfaction with life
# 96              How often get emotional support needed
# 97                       How often do you feel lonely?
# 98      Have you lost employment or had hours reduced?
# 99   During the past 12 months have you received fo...
# 100  How often did the food that you bought not las...
# 101               Were you not able to pay your bills?
# 102  Were you not able to pay utility bills or thre...
# 103  Has a lack of reliable transportation kept you...
# 104       How often have you felt this kind of stress?
# 105                                Metropolitan Status
# 106                                 Urban/Rural Status

# %%
variables = [
    "SEXVAR",
    "GENHLTH",
    "PHYSHLTH",
    "MENTHLTH",
    "POORHLTH",
    "PRIMINS1",
    "PERSDOC3",
    "MEDCOST1",
    "CHECKUP1",
    "EXERANY2",
    "EXRACT12",
    "EXEROFT1",
    "EXERHMM1",
    "EXRACT22",
    "EXEROFT2",
    "EXERHMM2",
    "STRENGTH",
    "ADDEPEV3",
    "MARITAL",
    "EDUCA",
    "RENTHOM1",
    "VETERAN3",
    "EMPLOY1",
    "CHILDREN",
    "INCOME3",
    "PREGNANT",
    "WEIGHT2",
    "HEIGHT3",
    "DEAF",
    "BLIND",
    "DECIDE",
    "DIFFWALK",
    "DIFFDRES",
    "DIFFALON",
    "SMOKE100",
    "SMOKDAY2",
    "ECIGNOW2",
    "ALCDAY4",
    "AVEDRNK3",
    "DRNK3GE5",
    "MAXDRNKS",
    "SOMALE",
    "SOFEMALE",
    "MARIJAN1",
    "ACEDEPRS",
    "ACEDRINK",
    "ACEDRUGS",
    "ACEPRISN",
    "ACEDIVRC",
    "ACEPUNCH",
    "ACEHURT1",
    "ACESWEAR",
    "ACETOUCH",
    "ACETTHEM",
    "ACEHVSEX",
    "ACEADSAF",
    "ACEADNED",
    "LSATISFY",
    "EMTSUPRT",
    "SDLONELY",
    "SDHEMPLY",
    "FOODSTMP",
    "SDHFOOD1",
    "SDHBILLS",
    "SDHUTILS",
    "SDHTRNSP",
    "SDHSTRE1",
    "_METSTAT",
    "_URBSTAT"
]

df_subset2 = metadata[metadata['SAS Variable Name'].isin(variables)]

df_subset2 = df_subset2.reset_index(drop=True)
df_subset2.shape
# Out:
# (429, 6)

# %%
# Join with dataframe to inspect data types and values
data = pd.read_csv("data/LLCP2023.csv")

# Subset columns to match df_subset2
data = data[data.columns.intersection(df_subset2['SAS Variable Name'])]

data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 433323 entries, 0 to 433322
# Data columns (total 69 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   SEXVAR    433323 non-null  float64
#  1   GENHLTH   433319 non-null  float64
#  2   PHYSHLTH  433320 non-null  float64
#  3   MENTHLTH  433320 non-null  float64
#  4   POORHLTH  252170 non-null  float64
#  5   PRIMINS1  433318 non-null  float64
#  6   PERSDOC3  433320 non-null  float64
#  7   MEDCOST1  433321 non-null  float64
#  8   CHECKUP1  433321 non-null  float64
#  9   EXERANY2  433321 non-null  float64
#  10  EXRACT12  325227 non-null  float64
#  11  EXEROFT1  323041 non-null  float64
#  12  EXERHMM1  323039 non-null  float64
#  13  EXRACT22  323040 non-null  float64
#  14  EXEROFT2  228757 non-null  float64
#  15  EXERHMM2  228757 non-null  float64
#  16  STRENGTH  433319 non-null  float64
#  17  ADDEPEV3  433320 non-null  float64
#  18  MARITAL   433316 non-null  float64
#  19  EDUCA     433314 non-null  float64
#  20  RENTHOM1  433315 non-null  float64
#  21  VETERAN3  432104 non-null  float64
#  22  EMPLOY1   430355 non-null  float64
#  23  CHILDREN  428231 non-null  float64
#  24  INCOME3   425248 non-null  float64
#  25  PREGNANT  76208 non-null   float64
#  26  WEIGHT2   422712 non-null  float64
#  27  HEIGHT3   421674 non-null  float64
#  28  DEAF      420248 non-null  float64
#  29  BLIND     419243 non-null  float64
#  30  DECIDE    418184 non-null  float64
#  31  DIFFWALK  417177 non-null  float64
#  32  DIFFDRES  416454 non-null  float64
#  33  DIFFALON  415463 non-null  float64
#  34  SMOKE100  413649 non-null  float64
#  35  SMOKDAY2  158639 non-null  float64
#  36  ECIGNOW2  411856 non-null  float64
#  37  ALCDAY4   407879 non-null  float64
#  38  AVEDRNK3  212126 non-null  float64
#  39  DRNK3GE5  211689 non-null  float64
#  40  MAXDRNKS  211286 non-null  float64
#  41  SOMALE    135790 non-null  float64
#  42  SOFEMALE  153467 non-null  float64
#  43  MARIJAN1  88613 non-null   float64
#  44  ACEDEPRS  56040 non-null   float64
#  45  ACEDRINK  55939 non-null   float64
#  46  ACEDRUGS  55891 non-null   float64
#  47  ACEPRISN  55845 non-null   float64
#  48  ACEDIVRC  55808 non-null   float64
#  49  ACEPUNCH  55758 non-null   float64
#  50  ACEHURT1  55687 non-null   float64
#  51  ACESWEAR  55621 non-null   float64
#  52  ACETOUCH  55554 non-null   float64
#  53  ACETTHEM  55486 non-null   float64
#  54  ACEHVSEX  55417 non-null   float64
#  55  ACEADSAF  55303 non-null   float64
#  56  ACEADNED  55224 non-null   float64
#  57  LSATISFY  226676 non-null  float64
#  58  EMTSUPRT  226318 non-null  float64
#  59  SDLONELY  225998 non-null  float64
#  60  SDHEMPLY  225739 non-null  float64
#  61  FOODSTMP  225475 non-null  float64
#  62  SDHFOOD1  225129 non-null  float64
#  63  SDHBILLS  224861 non-null  float64
#  64  SDHUTILS  224624 non-null  float64
#  65  SDHTRNSP  224266 non-null  float64
#  66  SDHSTRE1  223493 non-null  float64
#  67  _METSTAT  425000 non-null  float64
#  68  _URBSTAT  425000 non-null  float64
# dtypes: float64(69)
# memory usage: 228.1 MB
